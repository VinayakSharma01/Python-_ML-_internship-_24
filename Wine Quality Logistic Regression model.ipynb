# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split as TTS
from sklearn.linear_model import LogisticRegression as LOR
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,confusion_matrix
import seaborn as sns
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ***Table of content***
#
# **Basic Visualisation**
#
#  Maximum values
#
#  Minimum values
#
#  Description
#
# **Data visualisation**
#
#   Bar graph
#
#   Scatter graph

# %%
wq=pd.read_csv('winequality-red.csv')
wq
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wq.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wq.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
wq.max()
# Out:
# fixed acidity            15.90000
# volatile acidity          1.58000
# citric acid               1.00000
# residual sugar           15.50000
# chlorides                 0.61100
# free sulfur dioxide      72.00000
# total sulfur dioxide    289.00000
# density                   1.00369
# pH                        4.01000
# sulphates                 2.00000
# alcohol                  14.90000
# quality                   8.00000
# dtype: float64

# %%
wq.min()
# Out:
# fixed acidity           4.60000
# volatile acidity        0.12000
# citric acid             0.00000
# residual sugar          0.90000
# chlorides               0.01200
# free sulfur dioxide     1.00000
# total sulfur dioxide    6.00000
# density                 0.99007
# pH                      2.74000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 3.00000
# dtype: float64

# %%
wq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wq.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wq.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wq['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# ***BAR GRAPH***

# %%
sns.countplot(wq['quality'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
sns.countplot(wq['fixed acidity'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fixed acidity', ylabel='count'>

# %%
sns.countplot(wq['density'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='density', ylabel='count'>

# %%
sns.countplot(wq['alcohol'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='alcohol', ylabel='count'>

# %%
sns.countplot(wq['residual sugar'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='residual sugar', ylabel='count'>

# %%
sns.countplot(wq['pH'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pH', ylabel='count'>

# %%
wq.corrwith(wq.quality).plot.bar(figsize = (15, 6), title = "Correlation of Quality with other traits", fontsize = 15, rot = 45, grid = True)
# Out:
# <AxesSubplot:title={'center':'Correlation of Quality with other traits'}>

# %% [markdown]
# ***SCATTER GRAPH***

# %%
plt.scatter(wq['fixed acidity'],wq['quality'])
plt.show()

plt.scatter(wq['density'],wq['quality'])
plt.show()

plt.scatter(wq['alcohol'],wq['quality'])
plt.show()

plt.scatter(wq['residual sugar'],wq['quality'])
plt.show()

# %% [markdown]
# ***LINE GRAPH***

# %%
plt.figure(figsize=(20,8))

sns.lineplot(data=wq["fixed acidity"],linewidth=1.5,label="Fixed Acidity")
sns.lineplot(data=wq["quality"],linewidth=1.5,label="Quality")
plt.title("Fixed Acidity VS  Quality")

plt.ylabel("Fixed-Acidity")
plt.xlabel("Quality")
plt.show()

plt.figure(figsize=(20,8))

sns.lineplot(data=wq["density"],linewidth=1.5,label="Density")
sns.lineplot(data=wq["quality"],linewidth=1.5,label="Quality")
plt.title("Density VS  Quality")

plt.ylabel("Density")
plt.xlabel("Quality")
plt.show()

plt.figure(figsize=(20,8))

sns.lineplot(data=wq["alcohol"],linewidth=1.5,label="Alcohol")
sns.lineplot(data=wq["quality"],linewidth=1.5,label="Quality")
plt.title("Alcohol VS  Quality")

plt.ylabel("Alcohol")
plt.xlabel("Quality")
plt.show()

plt.figure(figsize=(20,8))

sns.lineplot(data=wq["residual sugar"],linewidth=1.5,label="Residual Sugar")
sns.lineplot(data=wq["quality"],linewidth=1.5,label="Quality")
plt.title("Residual Sugar VS  Quality")

plt.ylabel("Residual Sugar")
plt.xlabel("Quality")
plt.show()

# %% [markdown]
# ***HISTOGRAM***

# %%
wq.hist(figsize=(10,10))
plt.show()

# %%
wq['def_quality'] = [0 if x < 7 else 1 for x in wq['quality']]
X = wq.drop(['quality','def_quality'], axis = 1)
Y = wq['def_quality']

# %%
wq['def_quality'].value_counts()

fig = plt.figure(figsize=(22,8)) 
plt.subplot2grid((2,3),(0,0))
sns.countplot(wq['def_quality'])
plt.title("Proportion of wine according to its quality"); plt.ylabel("Count"); plt.xlabel("Type of wine")
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'Type of wine')

# %% [markdown]
# ***MACHINE LEARNING***

# %%
X=wq.drop(columns=['quality'])
Y=wq['quality']

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: def_quality, Length: 1599, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = TTS(X,Y,test_size=0.30,random_state=0)

# %%
model = LOR(max_iter=1000)
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_pred = model.predict(X_test)

# %%
DF_test_predict = X_test
DF_test_predict[" Y_test"] = Y_test
DF_test_predict[" Y_pred"] = Y_pred
DF_test_predict
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1109           10.8             0.470         0.43            2.10      0.171
# 1032            8.1             0.820         0.00            4.10      0.095
# 1002            9.1             0.290         0.33            2.05      0.063
# 487            10.2             0.645         0.36            1.80      0.053
# 979            12.2             0.450         0.49            1.40      0.075
# ...             ...               ...          ...             ...        ...
# 801             8.6             0.550         0.09            3.30      0.068
# 61              7.7             0.690         0.49            1.80      0.115
# 431             7.8             0.550         0.35            2.20      0.074
# 1210            6.8             0.650         0.02            2.10      0.078
# 713             8.0             0.430         0.36            2.30      0.075
#
# ...

# %%
CM=confusion_matrix(Y_test,Y_pred)
AS = accuracy_score(Y_test,Y_pred)
RS = recall_score(Y_test,Y_pred)
PS = precision_score(Y_test,Y_pred)
F1 = f1_score(Y_test,Y_pred)
print(f"   accuracy_score = {AS}\nrecall_score={RS} \nprecision_score={PS}\nf1_score {F1}")
# Out:
#    accuracy_score = 0.8979166666666667
# recall_score=0.34
# precision_score=0.5151515151515151
# f1_score 0.40963855421686746

# %%
plt.figure(figsize=(5,4))
sns.heatmap(CM,annot=True,fmt='d',cmap='Reds',
            xticklabels=["Good","Bad"],
            yticklabels=["Good","Bad"]
            )
plt.xlabel("Predected")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
